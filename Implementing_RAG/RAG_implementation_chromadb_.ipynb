# %%
#!pip install langchain sentence-transformers chromadb

# %%
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceInferenceAPIEmbeddings  # embeddings will not downloaded, it will directly run on cloud base.
from langchain.vectorstores import Chroma

from langchain.llms import HuggingFaceHub   # llm model
from langchain.chains import RetrievalQA

# %%
import os
from getpass import getpass

# %%
HF_token = getpass()
# Out:
# ··········

# %%
# creating environ for huggingface_api
os.environ["HUGGINGFACEHUB_API_TOKEN"] = HF_token

# %%
URL = "https://www.innomatics.in/"

# %%
data = WebBaseLoader(URL)

# %%
content = data.load()

# %%
print(content)
# Out:
# [Document(page_content=' Best Data Science & Big Data EdTech Company Hyderabad, India      \n   \n\n\n¬†+91 9951666670¬†|  ¬†For Inquiry:¬† +91 9347804375¬†|¬†+91 6304126766\nHomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n  HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n\nPay Now\n\n\uf8ffüìû 9951666670¬†+91 9951666670¬†|  ¬†For Inquiry:¬† +91 9347804375¬†|¬†+91 6304126766\nHomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n  HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n\nPay Now\n\n\uf8ffüìû9951666670HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n  HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend\n\nPay Now\n\n\n\uf8ffüìû9951666670\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n \n\n\n\n \n\n\n\n \n\n\n\n \n\n\n\n \n\n\n\n \n\n\nWe just don‚Äôt train,We transform the careersInnomatics Research Labs¬†is a pioneer in¬†‚ÄúTransforming Career and Lives‚Äù¬†of individuals in the Digital Space by catering advanced training on¬†IBM Certified Data Science, Python, IBM Certified Predictive Analytics Modeler, Machine Learning, Artificial Intelligence (AI),¬†Full-stack web development, Amazon Web Services (AWS), DevOps, Microsoft Azure, Big data Analytics,¬†Digital Marketing, and Career Launching program¬†for students¬†who are willing to showcase their skills in the competitive job market with valuable credentials, and also can complete courses with a certificate.IBM Registered Business PartnerAs an authorized¬†‚ÄúTraining Partner with IBM‚Äù we strive to make individuals learn not just algorithms but also case studies and challenges derived from businesses. To improve the effectiveness and productivity of our trainee¬†hackathons, workshops,¬†and¬†meetups¬†are conducted on a timely basis. Having a dedicated¬†placement vertical, which helps trainees conquer the business world, solves the complexities. Innomatics research labs are supporting¬†over 100 companies¬†in finding the best candidate, which can upskill the business requirements and foster growth.Best Edtech companyRecognized and rewarded by¬†Times Of India¬†as the¬†Best Training Institute in Hyderabad for Data Sci ...

# %% [markdown]
# # Chunking --> Text_splitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=256, chunk_overlap=5)

# %%
chunking = text_splitter.split_documents(content)

# %%
len(chunking)
# Out:
# 81

# %%
chunking
# Out:
# [Document(page_content='Best Data Science & Big Data EdTech Company Hyderabad, India', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='¬†+91 9951666670¬†|  ¬†For Inquiry:¬† +91 9347804375¬†|¬†+91 6304126766', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Pay Now', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='\uf8ffüìû 9951666670¬†+91 9951666670¬†|  ¬†For Inquiry:¬† +91 9347804375¬†|¬†+91 6304126766', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Pay Now', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='\uf8ffüìû9951666670HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Data Science InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='HomeCoursesData ScienceIBM Certified Data scienceOnline Data SciencePre-Placement ProgramData Science Summer InternshipFull Stack DevelopmentDigital MarketingAmazon Web Services (AWS)EventsFree Offline Data Science BootcampInternshipFree Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='InternshipData Science Summer InternshipAbout usAbout usPlacementsContact usBlogReviewsGalleryRefer a Friend', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Pay Now\n\n\n\uf8ffüìû9951666670', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='We just don‚Äôt train,We transform the careersInnomatics Research Labs¬†is a pioneer in¬†‚ÄúTransforming Career and Lives‚Äù¬†of individuals in the Digital Space by catering advanced training on¬†IBM Certified Data Science, Python, IBM Certified', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Predictive Analytics Modeler, Machine Learning, Artificial Intelligence (AI),¬†Full-stack web development, Amazon Web Services (AWS), DevOps, Microsoft Azure, Big data Analytics,¬†Digital Marketing, and Career Launching program¬†for students¬†who are', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='are willing to showcase their skills in the competitive job market with valuable credentials, and also can complete courses with a certificate.IBM Registered Business PartnerAs an authorized¬†‚ÄúTraining Partner with IBM‚Äù we strive to make individuals', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='learn not just algorithms but also case studies and challenges derived from businesses. To improve the effectiveness and productivity of our trainee¬†hackathons, workshops,¬†and¬†meetups¬†are conducted on a timely basis. Having a dedicated¬†placement', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='vertical, which helps trainees conquer the business world, solves the complexities. Innomatics research labs are supporting¬†over 100 companies¬†in finding the best candidate, which can upskill the business requirements and foster growth.Best Edtech', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='companyRecognized and rewarded by¬†Times Of India¬†as the¬†Best Training Institute in Hyderabad for Data Science & Digital Marketing Training.¬†With relentless hard work, sophisticated equipment, advanced classrooms, cutting-edge training methodologies,', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='practical training approach, and making individuals skillful. We have trained and placed 10000¬†students with a track record of 350+¬†batches, 200+¬†Hackathons, 150+¬†Industry Experts,¬†500+ Webinars, and 500+ Hiring Partners.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='View MoreWhat we are?ÔîÄGlobal Leaders in trainingWe have trainers hailing from the fortune companies who understand the real-time business cases and can train individuals based on them.ÔóºPractical oriented approachOur training methodology isn‚Äôt', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='confined to theoretical one; We have an exposure towards the real-time industry training by industry experts professionals.ÓÉ¥Hands-on projects & InternshipWe have trainers hailing from the fortune companies who understand the real-time business cases and', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='and can train individuals based on them.Ôïô100% Placement AssistanceWe promise Career Transformation; Having collaborations with top-notch companies and a dedicated placement vertical to help trainees aspire to aspirations.Trending Courses of 2023IBM', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Certified Data ScienceThis is a great choice for tech geeks, students, working professionals and aspiring data scientists who want to upskill and build a better foundation is the stream of Data Science.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreFull Stack DevelopmentLearn the right skills to break into a development career & advance yourself as a full-stack Developer. It includes Frontend, Backend, databases, debugging & testing.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreDigital MarketingDigital Marketing Course at Innomatics is perfect for Entrepreneurs, Freelancers, Job seekers, Wanna be Entrepreneurs, working professionals who want to enhance their skill.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreIBM Certified Predictive AnalyticsPredictive Analytics Modeler is to gain knowledge in analytics models to collect, data mining, data collection, data visualization, and integration, nodes, and statistical analysis.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreAmazon Web ServicesRight from the jobseeker or existing professional who wants to accelerate their career with advanced concepts of cloud computing, AWS and core services.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreDevopsThis is a must-learn course for the individuals who started her journey in the DevOps and cloud world and is ideally suited to developers, Cloud Admin, Solutions Architects and managers.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreAdvantages of training at InnomaticsFlexible Online Live and Classroom Training100% Internship guarantee programDedicated Placement verticalMastery level certifications that are globally acceptedBackup Classes & Lifetime LMS accessCompletely', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Practical Oriented ApproachHands-on training on the capstone projectsBi-weekly connects from industry expertsDomain Teach back and Reverse PresentationsFree Technical Support & Individual Career CounsellingExpert mentoring Weekly Tests &', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='& AssignmentsMock-up Exams, and InterviewsMeet-ups, Workshops, Hackathons & ConferencesExclusive programs for Non-IT professionalsLet‚Äôs Watch a Video Bite From Our Institute', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Watch More VideosWhy People Choose Our Trainingexpert trainersCapstone ProjectsInhouse InternshipPlacementsInnomatics explored all over India to get the best trainers and succeeded with it. We have a pool of trainers working with highly qualified business', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='partners and fortune companies to provide advanced and comprehensive training.¬†They curate the course content with an eye on the industry needs and standards to make students skilful and champions in solving the complex challenges of the industry.\xa0 At', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='At Innomatics, we believe in a practical learning approach. Making students work on real-time data helps in giving them a clear visualization of how it is applied in the real world.Considering this, we follow a collaborative group-oriented approach to', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='to learn with discussion forums and get hands-on with capstone projects to make our trainees good team players and strong thinkers to solve problems.Internships aren‚Äôt just about ground work at Innomatics. We believe that with the right program, One can', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='can develop young talents and lay a foundation for recruiting brilliant young minds to work for any organization.We do provide paid/unpaid internship programs that offer the opportunity to edge out larger competitors by providing interns with', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='with opportunities to conquer the business challenges.We have a collaboration with over 100+ MNCs and SMEs who directly source their business requirements through Innomatics. Also having a dedicated placement verticle that enables trainees to take', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='take advantage and excel in the career with extensive knowledge gained at Innomatics.For the benefit of the students to face the real challenges, we conduct mockup interviews with instant feedback,1-1 mentorship, provide extensive support to the Learning', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Management System(LMS) where they can access the classes and stay updated, attend career fairs, Hackathons, workshops and meetups with leading industry experts.Why People Choose Our TrainingYour Title Goes HereYour content goes here. Edit or remove this', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='this text inline or in the module Content settings. You can also style every aspect of this content in the module Design settings and even apply custom CSS to this text in the module Advanced settings.EXPERT TRAINERSInnomatics explored all over India to', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='to get the best trainers and succeeded with it. We have a pool of trainers working with highly qualified business partners and fortune companies to provide advanced and comprehensive training.¬†They curate the course content with an eye on the industry', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='needs and standards to make students skilful and champions in solving the complex challenges of the industry.CAPSTONE PROJECTS At Innomatics, we believe in a practical learning approach. Making students work on real-time data helps in giving them a clear', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='visualization of how it is applied in the real world.Considering this, we follow a collaborative group-oriented approach to learn with discussion forums and get hands-on with capstone projects to make our trainees good team players and strong thinkers to', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='to solve problems.INHOUSE INTERNSHIPInternships aren‚Äôt just about ground work at Innomatics. We believe that with the right program, One can develop young talents and lay a foundation for recruiting brilliant young minds to work for any organization.We', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='do provide paid/unpaid internship programs that offer the opportunity to edge out larger competitors by providing interns with opportunities to conquer the business challenges.PLACEMENTS¬†We have a collaboration with over 100+ MNCs and SMEs who directly', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='source their business requirements through Innomatics. Also having a dedicated placement verticle that enables trainees to take advantage and excel in the career with extensive knowledge gained at Innomatics.For the benefit of the students to face the', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='the real challenges, we conduct mockup interviews with instant feedback,1-1 mentorship, provide extensive support to the Learning Management System(LMS) where they can access the classes and stay updated, attend career fairs, Hackathons, workshops and', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='and meetups with leading industry experts.Meet our experts', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='9951666670A few reviews from our studentsSindhujaInnomatics is one of the best places to gain knowledge on data science and also get certified through IBM which can help in getting the right jobs from top companies. Tutors will teach you with real-time', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='examples to understand the concepts in an easy way. Special thanks to Vaibav Sir who taught each concept very clearly.Vamshi RajInnomatics Research Labs is the Best platform to transform our career, here I have done a Data analytics course, and was', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='was recently placed in a company.Here they provides Excellent quality education and practice or doubt Sessions. and conducts so many Hackathons to enhance our skills. I personally like the LMS facility which is lifetime. Here we can see all our class', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='recordings throughout the course.Faculty and staff are so friendly. They will guide us until we get placed.Pramodha‚≠êÔ∏è‚≠êÔ∏è‚≠êÔ∏è‚≠êÔ∏è‚≠êÔ∏èI am incredibly grateful to my institute for the invaluable support they provided in my job search journey.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='The guidance and resources they offered were instrumental in helping me secure a job. I want to express my special thanks to our HR executive, Sai Kiran Rodda, whose assistance was pivotal. His dedication and expertise made the entire process seamless,', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='enabling me to transition smoothly into my new role. I highly recommend this institute to anyone seeking not only quality education but also excellent career support. Thank you for making a significant difference in my life!Amarnath ChoudaryHEY! I am Amar', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Amar student of the innomatics research labs .. I love the innomatics research lab because the mentors and trainers help me a lot in any query in the course. If anyone looking for data science in the market, I can say innomatics is one of the best', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='best institutes.', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read MoreHere Are Some Of Our Success Stories', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Read Latest Business News & Blog updates\xa0OOPS Concepts in Python: Part 1Class, Objects, Constructor, Methods in Python : What is Object-Oriented Programming (OOPs)? In Python,...Real-world Applications of Data Science in Today’s Fast-paced EnvironmentData', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='science is a field that has emerged as an essential job avenue and has a wide range of real-time applications....Top 7 Full Stack Development Trends To Follow As consumerism increases so do the need for user-friendly apps. This is where a...Why should you', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='you join Innomatics?At Innomatics we believe in looking at the larger picture and forecasting which direction the industry is moving. We...7 Things to know before you start your career in Data ScienceAround 82,000 job openings are present worldwide in', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='in 2021 that require skills in Data Science and around 92% of the...How To Start a Data Science Course to become a data scientist?Today, the value of data is revolutionary in the modern digital economy. The statistical methods and the discovery of...«', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Older Entries', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='A leading training institute, Innomatics Research Labs offers courses in areas such as IBM Certified Data Science, Python, AI, Data Analytics, Full Stack Development, and Digital Marketing. Our practical training is designed meticulously to meet industry', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='needs and provide valuable certification upon completion, empowering individuals to excel in their careers.FollowFollowFollowFollowFollowCoursesIBM Certified Data ScienceOnline Data ScienceDigital MarketingAmazon Web Services (AWS)Full Stack Web', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Web DeveloperRefer a FriendPlacementsPrivacy PolicyContact Details:ÓÇÅKukatpally#205, 2nd Floor, Fortune Signature, Near JNTU Metro Station, Kukatpally, Hyderabad, Telangana 500085\xa0ÓÇÅGachibowli2nd Floor, Leeway, BP Raju Marg, Opp. Sarath City Capital', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='Mall, Beside Subbayagari Hotel, Laxmi Cyber City, Whitefields, Kondapur, Telangana 500081ÓÇêPhone/Whatsapp:¬†', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='+91-9951666670¬†/¬†+91-6304126766¬†¬†/¬†+91-9347804375ÓÅ∂For Course:¬†[email\xa0protected]¬© 2023 Innomatics Research Labs Pvt Ltd, All rights reserved.Enroll Here for the CourseEnquiry form', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..IBM certified Data ScienceFull Stack DevelopmentDS Summer Training and InternshipTraining ModeSelect Training ModeOnlineClassroomRegister Now\nX\t\t\tEnroll Here for the CourseEnquiry form', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..IBM certified Data ScienceFull Stack DevelopmentDS Summer Training and InternshipTraining ModeSelect Training ModeOnlineClassroomRegister Now\nX', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='X\t\t\t\nDs summer training and internshipBrochure-DS intensive and internship \nFirst NameContact NumberEmail IdSelect CourseSelect Course..Data Science summer training and internshipRegister Now\nCLOSE\t\t\tPlease fill your detailsBrochure-Data Science', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..IBM certified Data ScienceTraining ModeSelect Training ModeOnlineClassroomRegister Now\nX\t\t\tL2 Brochure-DS for working professionals (#14)', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..Data Science for working professionalsTraining ModeSelect Training ModeOnlineClassroomRegister Now\nCLOSE\t\t\tDS summer training and internship', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..DS summer training and internshipRegister Now\nCLOSE\t\t\tPlease fill your detailsBrochure-Digital Marketing', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..Digital MarketingTraining ModeSelect Training ModeOnlineClassroomRegister Now\nX\t\t\tPlease fill your detailsBrochure-Fullstack development', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'}),
#  Document(page_content='First NameContact NumberEmail IdSelect CourseSelect Course..Full Stack DevelopmentTraining ModeSelect Training ModeOnlineClassroomRegister Now\nX', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'})]

# %%
chunking[0]
# Out:
# Document(page_content='Best Data Science & Big Data EdTech Company Hyderabad, India', metadata={'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India', 'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US'})

# %% [markdown]
# # HuggingFace --> Embeddings model

# %%
embeddings = HuggingFaceInferenceAPIEmbeddings(api_key = HF_token,
                                                model_name = "BAAI/bge-base-en-v1.5")

# %%
embeddings
# Out:
# HuggingFaceInferenceAPIEmbeddings(api_key=SecretStr('**********'), model_name='BAAI/bge-base-en-v1.5', api_url=None)

# %%
# storing embeddings vectors
vectore_store = Chroma.from_documents(chunking, embeddings)  # Chroma.from_documents --> responsible for processing documents or text data.

# %%
vectore_store

# %% [markdown]
# # huggingface --> retrieving our model (HuggingFaceH4/zephyr-7b-alpha), which is fine-tuned model of mistral model.

# %%
model = HuggingFaceHub(repo_id = "HuggingFaceH4/zephyr-7b-alpha",
                       model_kwargs = {"temperature":0.5, "max_new_tokens":512, "max_length":64})

# %% [markdown]
# # step1 : Retriever

# %%
retriever = vectore_store.as_retriever(search_type = "mmr", search_kwarg={"k":5})

# %%
query = "which courses are providing by innomatics"

# %%
doc_rel = retriever.get_relevant_documents(query)
doc_rel
# Out:
# [Document(page_content='A leading training institute, Innomatics Research Labs offers courses in areas such as IBM Certified Data Science, Python, AI, Data Analytics, Full Stack Development, and Digital Marketing. Our practical training is designed meticulously to meet industry', metadata={'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US', 'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India'}),
#  Document(page_content='Read MoreDigital MarketingDigital Marketing Course at Innomatics is perfect for Entrepreneurs, Freelancers, Job seekers, Wanna be Entrepreneurs, working professionals who want to enhance their skill.', metadata={'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US', 'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India'}),
#  Document(page_content='Read MoreAdvantages of training at InnomaticsFlexible Online Live and Classroom Training100% Internship guarantee programDedicated Placement verticalMastery level certifications that are globally acceptedBackup Classes & Lifetime LMS accessCompletely', metadata={'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US', 'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India'}),
#  Document(page_content='take advantage and excel in the career with extensive knowledge gained at Innomatics.For the benefit of the students to face the real challenges, we conduct mockup interviews with instant feedback,1-1 mentorship, provide extensive support to the Learning', metadata={'description': 'Recognized & Rewarded by Times Of India as the Best Training Institute for the Data Science & Digital Marketing. Training Partner with IBM.', 'language': 'en-US', 'source': 'https://www.innomatics.in/', 'title': 'Best Data Science & Big Data EdTech Company Hyderabad, India'})]

# %%
#retriever1 = vectore_store.as_retriever(search_type="mmr", search_kwarg={"k":6})

# %% [markdown]
# ## step2 : Prompt Augmentation (system_prompt)

# %%
query = "which courses are providing by innomatics"

# %%
prompt = f"""
<|system|>
you are an AI assistant that follows instructions extremely well.
please be truthful and give direct answers.
</s>

<|user|>
{query}
</s>
<|assistant|>
"""

# %% [markdown]
# # step3 : Generation

# %%
qa = RetrievalQA.from_chain_type(llm=model, retriever=retriever, chain_type = "stuff")

# %%
response = qa(prompt)

# %%
response
# Out:
# {'query': '\n<|system|>\nyou are an AI assistant that follows instructions extremely well.\nplease be truthful and give direct answers.\n</s>\n\n<|user|>\nwhich courses are providing by innomatics\n</s>\n<|assistant|>\n',
#  'result': "Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.\n\nAmar student of the innomatics research labs .. I love the innomatics research lab because the mentors and trainers help me a lot in any query in the course. If anyone looking for data science in the market, I can say innomatics is one of the best\n\n+91-9951666670¬†/¬†+91-6304126766¬†¬†/¬†+91-9347804375ÓÅ∂For Course:¬†[email\xa0protected]¬© 2023 Innomatics Research Labs Pvt Ltd, All rights reserved.Enroll Here for the CourseEnquiry form\n\nRead MoreAdvantages of training at InnomaticsFlexible Online Live and Classroom Training100% Internship guarantee programDedicated Placement verticalMastery level certifications that are globally acceptedBackup Classes & Lifetime LMS accessCompletely\n\nDevRel @AI PlanetðŸ¥‘ ||  AI with Tarun- YouTubeðŸ¤—||  GDE in MLðŸš€ ||  GSoC'23 caMicroscope\nKnow more\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout Me\n\nQuestion: \n<|system|>\nyou are an AI assistant that follows instructions extremely well.\nplease be truthful and give direct answers.\n</s>\n\n<|user|>\nwhich courses are providing by innomatics\n</s>\n<|assistant|>\n\nHelpful Answer:\n\nInnomatics Research Labs Pvt Ltd offers various courses in the field of data science, artificial intelligence, machine learning, and big data analytics. Some of the popular courses offered by Innomatics are:\n\n1. Data Science with Python\n2. Machine Learning with R\n3. Big Data Analytics with Hadoop\n4. Deep Learning with Keras\n5. Data Visualization with Tableau\n6. Data Engineering with Spark\n7."}

# %%
print(response["result"])
# Out:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# Amar student of the innomatics research labs .. I love the innomatics research lab because the mentors and trainers help me a lot in any query in the course. If anyone looking for data science in the market, I can say innomatics is one of the best
#
# +91-9951666670¬†/¬†+91-6304126766¬†¬†/¬†+91-9347804375ÓÅ∂For Course:¬†[email protected]¬© 2023 Innomatics Research Labs Pvt Ltd, All rights reserved.Enroll Here for the CourseEnquiry form
#
# Read MoreAdvantages of training at InnomaticsFlexible Online Live and Classroom Training100% Internship guarantee programDedicated Placement verticalMastery level certifications that are globally acceptedBackup Classes & Lifetime LMS accessCompletely
#
# DevRel @AI PlanetðŸ¥‘ ||  AI with Tarun- YouTubeðŸ¤—||  GDE in MLðŸš€ ||  GSoC'23 caMicroscope
# Know more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Me
#
# Question:
# <|system|>
# you are an AI assistant that follows instructions extremely well.
# please be truthful and give direct answers.
# </s>
#
# <|user|>
# which courses are providing by innomatics
# </s>
# <|assistant|>
#
# Helpful Answer:
#
# Innomatics Research Labs Pvt Ltd offers various courses in the field of data science, artificial intelligence, machine learning, and big data analytics. Some of the popular courses offered by Innomatics are:
#
# 1. Data Science with Python
# 2. Machine Learning with R
# 3. Big Data Analytics with Hadoop
# 4. Deep Learning with Keras
# 5. Data Visualization with Tableau
# 6. Data Engineering with Spark
# 7.
